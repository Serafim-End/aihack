# %%
import pandas as pd
import numpy as np

# %%
X_train = pd.read_csv('df_train_stat_2.csv')
X_test = pd.read_csv('df_test_stat_2.csv')

# %%
(X_train[X_train['Revisit']==1].shape[0]/X_train.shape[0]) / (X_train[X_train['Revisit']==0].shape[0]/X_train.shape[0])
# Out:
# 4.835621521335807

# %%
X_train.drop(['Unnamed: 0'], axis=1, inplace=True)
X_train = X_train.set_index('ID')

X_test.drop(['Unnamed: 0'], axis=1, inplace=True)
X_test = X_test.set_index('ID')

# %%
X_raw_train = pd.read_csv('train_data.csv')
X_raw_test = pd.read_csv('test_data.csv')

# %%
X_raw_train = X_raw_train.set_index('ID')
X_raw_test = X_raw_test.set_index('ID')

# %%
X_raw_train[X_raw_train['Код_диагноза'].str.startswith('Z')]
# Out:
#        Код_диагноза                                            Диагноз  \
# ID
# 4             Z00.0                           Общий медицинский осмотр
# 5               Z01  Другие специальные осмотры и обследования лиц,...
# 27            Z00.0                           Общий медицинский осмотр
# 28            Z01.4   Гинекологическое обследование (общее) (рутинное)
# 40            Z32.1                        Беременность подтвержденная
# 41            Z01.4   Гинекологическое обследование (общее) (рутинное)
# 52            Z00.8                               Другие общие осмотры
# 68            Z00.0                           Общий медицинский осмотр
# 89            Z01.8         Другое уточненное специальное обследование
# 107             Z01  Другие специальные осмотры и обследования лиц,...
# 136           Z32.1                        Беременность подтвержденная
# 160           Z01.8         Другое уточненное специальное обследование
# ...

# %%
X_raw_train[X_raw_train['']]

# %%
X_raw_train['code_1'] = X_raw_train['Код_диагноза'].str[1:3].map(int)
X_raw_test['code_1'] = X_raw_test['Код_диагноза'].str[1:3].map(int)

# %%
X_raw_train['code_0'] = X_raw_train['Код_диагноза'].str[:1]
X_raw_test['code_0'] = X_raw_test['Код_диагноза'].str[:1]

# %%
# Out:
#        Код_диагноза                                            Диагноз  \
# ID
# 3681          Z97.5  Наличие (внутриматочного) контацептивного сред...
# 5331            Z98                Другие послехирургические состояния
# 14745         Z97.5  Наличие (внутриматочного) контацептивного сред...
# 15611         Z96.1                        Наличие интраокулярных линз
# 16882         Z89.4  Приобретенное отсутствие стопы и голеностопног...
# 24741         Z92.0  Личный анамнез применения противозачаточных ср...
# 28229         Z92.0  Личный анамнез применения противозачаточных ср...
# 30813         Z97.5  Наличие (внутриматочного) контацептивного сред...
# 36651         Z92.0  Личный анамнез применения противозачаточных ср...
# 40699         Z88.9  В личном анамнезе аллергия к неуточненным лека...
# 41010         Z92.0  Личный анамнез применения противозачаточных ср...
# 45201         Z92.0  Личный анамнез применения противозачаточных ср...
# ...

# %%
# X_train.index
# Out:
# ID
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 283056    False
# 283057    False
# 283058    False
# 283059    False
# 283060    False
# 283061    False
# 283062    False
# 283063    False
# 283064    False
# 283065    False
# 283066    False
# 283067    False
# 283068    False
# 283069    False
# 283070    False
# 283071    False
# 283072    False
# 283073    False
# 283074    False
# 283075    False
# 283076    False
# 283077    False
# 283078    False
# 283079    False
# ...

# %%
C_train = pd.DataFrame(
    data={'z_code_last': (X_raw_train['code_0']=='Z') & (X_raw_train['code_1'] > 80)},
    index=X_train.index
)

C_test = pd.DataFrame(
    data={'z_code_last': (X_raw_test['code_0']=='Z') & (X_raw_test['code_1'] > 80)},
    index=X_test.index
)

# %%
C_train['z_code_70'] = (X_raw_train['code_0']=='Z') & (X_raw_train['code_1'] >= 70) & (X_raw_train['code_1'] <= 76)
C_test['z_code_70'] = (X_raw_test['code_0']=='Z') & (X_raw_test['code_1'] >= 70) & (X_raw_test['code_1'] <= 76)

# %%
C_train['z_code_60'] = (X_raw_train['code_0']=='Z') & (X_raw_train['code_1'] >= 55) & (X_raw_train['code_1'] <= 65)
C_test['z_code_60'] = (X_raw_test['code_0']=='Z') & (X_raw_test['code_1'] >= 55) & (X_raw_test['code_1'] <= 65)

# %%
C_train['z_code_40'] = (X_raw_train['code_0']=='Z') & (X_raw_train['code_1'] >= 40) & (X_raw_train['code_1'] <= 54)
C_test['z_code_40'] = (X_raw_test['code_0']=='Z') & (X_raw_test['code_1'] >= 40) & (X_raw_test['code_1'] <= 54)

# %%
C_train['z_code_30'] = (X_raw_train['code_0']=='Z') & (X_raw_train['code_1'] >= 30) & (X_raw_train['code_1'] <= 39)
C_test['z_code_30'] = (X_raw_test['code_0']=='Z') & (X_raw_test['code_1'] >= 30) & (X_raw_test['code_1'] <= 39)

# %%
C_train['z_code_20'] = (X_raw_train['code_0']=='Z') & (X_raw_train['code_1'] >= 20) & (X_raw_train['code_1'] <= 29)
C_test['z_code_20'] = (X_raw_test['code_0']=='Z') & (X_raw_test['code_1'] >= 20) & (X_raw_test['code_1'] <= 29)

# %%
C_train['z_code_13'] = (X_raw_train['code_0']=='Z') & (X_raw_train['code_1'] <= 13)
C_test['z_code_13'] = (X_raw_test['code_0']=='Z') & (X_raw_test['code_1'] <= 13)
